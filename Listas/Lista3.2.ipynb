# %% [markdown]
# Fáceis
#
# 2. Contar elementos:
# Dada uma tupla mista (números e strings), conte quantos são strings.
# 3. Índice de um valor:
# Encontre o índice da primeira ocorrência de um valor em uma tupla.
# 4. Converter lista em tupla:
# Peça uma lista ao usuário e converta para tupla. Exiba o tipo resultante.

# %% [markdown]
# 1. Criar tupla e acessar:
# Crie uma tupla com 5 nomes de cidades e exiba o terceiro elemento.

# %%
cidades = ("Curitiba", )
